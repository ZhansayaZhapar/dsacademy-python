# %% [markdown]
# # PANDAS VISUALIZATION
# ## HW 3

# %%
import pandas as pd
import numpy as np
import os

from sklearn import preprocessing

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
path = os.getcwd()
files = os.listdir(path)
files_csv = [f for f in files if f[-3:] == 'csv']
files_csv
# Out:
# ['2015.csv', '2016.csv', '2017.csv']

# %%
n = len(files_csv)

# %%
n
# Out:
# 3

# %%
df_raw = pd.DataFrame()

for i in range(n):
    data = pd.read_csv(files_csv[i])
    data['Year'] = int(files_csv[i][0:4])
    df_raw = df_raw.append(data)

df_raw = df_raw.fillna(0)

# %%
df_raw.head()
# Out:
#        Country  Dystopia Residual  Dystopia.Residual  \
# 0  Switzerland            2.51738                NaN
# 1      Iceland            2.70201                NaN
# 2      Denmark            2.49204                NaN
# 3       Norway            2.46531                NaN
# 4       Canada            2.45176                NaN
#
#    Economy (GDP per Capita)  Economy..GDP.per.Capita.   Family  Freedom  \
# 0                   1.39651                       NaN  1.34951  0.66557
# 1                   1.30232                       NaN  1.40223  0.62877
# 2                   1.32548                       NaN  1.36058  0.64938
# 3                   1.45900                       NaN  1.33095  0.66973
# 4                   1.32629                       NaN  1.32261  0.63297
#
#    Generosity  Happiness Rank  Happiness Score  ...  Health..Life.Expectancy.  \
# 0     0.29678             1.0            7.587  ...                       NaN
# 1     0.43630             2.0            7.561  ...                       NaN
# 2     0.34139             3.0            7.527  ...                       NaN
# 3     0.34699             4.0            7.522  ...                       NaN
# 4     0.45811             5.0            7.427  ...                       NaN
#
#    Lower Confidence Interval          Region  Standard Error  \
# 0                        NaN  Western Europe         0.03411
# 1                        NaN  Western Europe         0.04884
# 2                        NaN  Western Europe         0.03328
# 3                        NaN  Western Europe         0.03880
# 4                        NaN   North America         0.03553
#
#    Trust (Government Corruption) Trust..Government.Corruption.  \
# 0                        0.41978                           NaN
# 1                        0.14145                           NaN
# 2                        0.48357                           NaN
# 3                        0.36503                           NaN
# 4                        0.32957                           NaN
#
#    Upper Confidence Interval  Whisker.high  Whisker.low  Year
# 0                        NaN           NaN          NaN  2015
# 1                        NaN           NaN          NaN  2015
# 2                        NaN           NaN          NaN  2015
# 3                        NaN           NaN          NaN  2015
# 4                        NaN           NaN          NaN  2015
#
# [5 rows x 23 columns]

# %%
df_raw.tail()
# Out:
#                       Country  Dystopia Residual  Dystopia.Residual  \
# 150                    Rwanda                NaN           0.540061
# 151                     Syria                NaN           1.061574
# 152                  Tanzania                NaN           0.621130
# 153                   Burundi                NaN           1.683024
# 154  Central African Republic                NaN           2.066005
#
#      Economy (GDP per Capita)  Economy..GDP.per.Capita.    Family   Freedom  \
# 150                       NaN                  0.368746  0.945707  0.581844
# 151                       NaN                  0.777153  0.396103  0.081539
# 152                       NaN                  0.511136  1.041990  0.390018
# 153                       NaN                  0.091623  0.629794  0.059901
# 154                       NaN                  0.000000  0.000000  0.270842
#
#      Generosity  Happiness Rank  Happiness Score  ...  \
# 150    0.252756             NaN              NaN  ...
# 151    0.493664             NaN              NaN  ...
# 152    0.354256             NaN              NaN  ...
# 153    0.204435             NaN              NaN  ...
# 154    0.280876             NaN              NaN  ...
#
#      Health..Life.Expectancy.  Lower Confidence Interval  Region  \
# 150                  0.326425                        NaN     NaN
# 151                  0.500533                        NaN     NaN
# 152                  0.364509                        NaN     NaN
# 153                  0.151611                        NaN     NaN
# 154                  0.018773                        NaN     NaN
#
#      Standard Error  Trust (Government Corruption)  \
# 150             NaN                            NaN
# 151             NaN                            NaN
# 152             NaN                            NaN
# 153             NaN                            NaN
# 154             NaN                            NaN
#
#     Trust..Government.Corruption.  Upper Confidence Interval  Whisker.high  \
# 150                      0.455220                        NaN      3.543030
# 151                      0.151347                        NaN      3.663669
# 152                      0.066035                        NaN      3.461430
# 153                      0.084148                        NaN      3.074690
# 154                      0.056565                        NaN      2.864884
#
#      Whisker.low  Year
# 150     3.398970  2017
# 151     3.260331  2017
# 152     3.236570  2017
# 153     2.735310  2017
# 154     2.521116  2017
#
# [5 rows x 23 columns]

# %%
df_raw['Year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int64)

# %%
df_raw['Year'].dtype
# Out:
# dtype('int64')

# %%
for i in df_raw.columns:
    print(i)
# Out:
# Country
# Dystopia Residual
# Dystopia.Residual
# Economy (GDP per Capita)
# Economy..GDP.per.Capita.
# Family
# Freedom
# Generosity
# Happiness Rank
# Happiness Score
# Happiness.Rank
# Happiness.Score
# Health (Life Expectancy)
# Health..Life.Expectancy.
# Lower Confidence Interval
# Region
# Standard Error
# Trust (Government Corruption)
# Trust..Government.Corruption.
# Upper Confidence Interval
# Whisker.high
# Whisker.low
# Year

# %%
df_raw['Dystopia Residual'] = df_raw['Dystopia Residual'] + df_raw['Dystopia.Residual']
df_raw['Economy (GDP per Capita)'] = df_raw['Economy (GDP per Capita)'] + df_raw['Economy..GDP.per.Capita.']
df_raw['Happiness Rank'] = df_raw['Happiness Rank'] + df_raw['Happiness.Rank']
df_raw['Happiness Score'] = df_raw['Happiness Score'] + df_raw['Happiness.Score']
df_raw['Health (Life Expectancy)'] = df_raw['Health (Life Expectancy)'] + df_raw['Health..Life.Expectancy.']
df_raw['Trust (Government Corruption)'] = df_raw['Trust (Government Corruption)'] + df_raw['Trust..Government.Corruption.']



#Whisker.high
#Whisker.low






df_raw = df_raw.drop('Dystopia.Residual', 'Economy..GDP.per.Capita.', 'Happiness.Rank', axis = 1)

# %%
df_raw[df['Country'] == 'Denmark']
# Out:
#    Country  Dystopia Residual  Economy (GDP per Capita)  \
# 2  Denmark           2.492040                   1.32548
# 0  Denmark           2.739390                   1.44178
# 1  Denmark           2.313707                   0.00000
#
#    Economy..GDP.per.Capita.    Family   Freedom  Generosity  Happiness Rank  \
# 2                  0.000000  1.360580  0.649380     0.34139             3.0
# 0                  0.000000  1.163740  0.579410     0.36171             1.0
# 1                  1.482383  1.551122  0.626007     0.35528             0.0
#
#    Happiness Score  Happiness.Rank  ...  Health..Life.Expectancy.  \
# 2            7.527             0.0  ...                  0.000000
# 0            7.526             0.0  ...                  0.000000
# 1            0.000             2.0  ...                  0.792566
#
#    Lower Confidence Interval          Region  Standard Error  \
# 2                       0.00  Western Europe         0.03328
# 0                       7.46  Western Europe         0.00000
# 1                       0.00               0         0.00000
#
#   Trust (Government Corruption)  Trust..Government.Corruption.  \
# 2                       0.48357                        0.00000
# 0                       0.44453                        0.00000
# 1                       0.00000                        0.40077
#
#    Upper Confidence Interval  Whisker.high  Whisker.low  Year
# 2                      0.000      0.000000     0.000000  2015
# 0                      7.592      0.000000     0.000000  2016
# 1                      0.000      7.581728     7.462272  2017
#
# [3 rows x 22 columns]
